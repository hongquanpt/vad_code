# %% [markdown]
# # How to run Tensorboard in JupyterNotebook
#
# - https://www.oreilly.com/library/view/hands-on-tensorboard-for/9781838983604/video1_4.html
# - https://www.tensorflow.org/tensorboard/tensorboard_in_notebooks
# - Run %load_ext tensorboard in one cell, then %tensorboard --logdir logs/fit in a second cell

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# Start TensorBoard 
tensorboard_dirpath = '/home/anhnam/Data/VAD/output/train/PAMAE/ped2/001-2023-08-06-10-00/tensorboard'
# %tensorboard --logdir tensorboard_dirpath
# Out:
#       <iframe id="tensorboard-frame-ffa56275c13697dc" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ffa56275c13697dc");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from tensorboard import notebook

# View open TensorBoard instances
notebook.list()
# Out:
# Known TensorBoard instances:
#   - port 6008: logdir tensorboard_dirpath (started 0:07:47 ago; pid 228185)
#   - port 6007: logdir tensorboard_dirpath (started 0:10:46 ago; pid 227967)
#   - port 6006: logdir run (started 0:12:11 ago; pid 227741)

# %%
# Control TensorBoard display. If no port is provided, 
# the most recently launched TensorBoard is used
notebook.display(port=6008, height=1000)
# Out:
# Selecting TensorBoard with logdir tensorboard_dirpath (started 0:11:05 ago; port 6008, pid 228185).
#       <iframe id="tensorboard-frame-de663ea9c826c134" width="100%" height="1000" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-de663ea9c826c134");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # ssh server ubuntu
# - https://linuxize.com/post/how-to-enable-ssh-on-ubuntu-20-04/
# - If you don’t know your IP address you can easily find it using the ip command in terminal : ip a
# ![image.png](attachment:d9092f76-3f26-4aa5-a034-f5150b183712.png)![image.png](attachment:195d2be3-6ba0-4d72-952e-9a17f8165e1c.png)

# %% [markdown]
# - server ip address: 192.168.2.27/24

# %% [markdown]
# # reverse proxy Ngrok
# - https://stackoverflow.com/questions/37987839/how-can-i-run-tensorboard-on-a-remote-server
# - Another approach is to use a reverse proxy, which allows you to view Tensorboard from any internet connected device without SSHing. This approach can make it far easier / tractable to view Tensorboard on mobile devices, for example. Steps:
#
# - 1) Download reverse proxy Ngrok on your remote machine hosting Tensorboard. See https://ngrok.com/download for instructions (~5 minute setup).
# - 2) Run ngrok http 6006 (assuming you're hosting Tensorboard on port 6006)
# - 3) Save the URL that ngrok outputs:

# %% [markdown]
# # Giải pháp sử dụng terminal ở máy chủ
# - Mở terminal lên
# - conda activate pyanomaly
# - đánh lệnh sau: tensorboard --logdir='/home/anhnam/Data/VAD/output/train/PAMAE/ped2/001-2023-08-06-10-00/tensorboard'
# - sau đó click vào đường link hiện ở dưới trong terminal: http://localhost:6006, hoặc các port khác.  thì tensorboard hiện lên.
# - muốn thoát khởi tensorboard thì ấn Ctrl+C trong terminal
