# %%
devices = "cuda:0" # "cuda:0"; "cuda:1"; "cpu"

# Split the GPU indices based on the comma
device = devices.split(':')[0]
device_ids = devices.split(':')[1]
print(f'device = {device}')

device_ids = device_ids.split(',')
print(f'device_ids = {device_ids}')

# Convert the GPU indices to integers
device_ids = [int(idx) for idx in indices]
print(f'device_ids = {device_ids}')

#===========
# Out:
# device = cuda
# device_ids = ['0', '1']
# device_ids = [0, 1]

# %%
import torch

device = 'cuda:0' # "cuda:0"; "cuda:1"; "cpu"
device = torch.device(device)
print(f'device = {device}')
print(f'torch.cuda.device_count() = {torch.cuda.device_count()}')
# Out:
# device = cuda:0
# torch.cuda.device_count() = 2

# %%
import torch

cls_labels = [0, 1, 0]

cls_labels_0 = torch.Tensor(cls_labels).unsqueeze(0)
cls_labels_1 = torch.Tensor(cls_labels).unsqueeze(1)

print('cls_labels_0 = ', cls_labels_0)
print('cls_labels_0.shape = ', cls_labels_0.shape)

print('cls_labels_1 = ', cls_labels_1)
print('cls_labels_1.shape = ', cls_labels_1.shape)
# Out:
# cls_labels_0 =  tensor([[0., 1., 0.]])
# cls_labels_0.shape =  torch.Size([1, 3])
# cls_labels_1 =  tensor([[0.],
#         [1.],
#         [0.]])
# cls_labels_1.shape =  torch.Size([3, 1])
