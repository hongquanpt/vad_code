# %%
import numpy as np

arr = np.load('frame_labels_ped2.npy')
ground_th = arr[0][0:100]
print(f'arr.shape = {arr.shape}')
print(f'ground_th.shape = {ground_th.shape}')
# Out:
# arr.shape = (1, 2010)
# ground_th.shape = (100,)
