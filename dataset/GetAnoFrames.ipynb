# %%
# !pip install natsort
import numpy as np
import os
import sys
import cv2
import math
import glob

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torch.nn.init as init
import torch.utils.data as data
import torch.utils.data.dataset as dataset
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.autograd import Variable
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from collections import OrderedDict
def get_augly_data(dataset):
    labels = np.load('./data/frame_labels_'+dataset+'.npy')
    data_folder = "/home/namvd/data/Dataset"
    data_folder = data_folder+'/'+dataset+"/testing/frames"
    videos = OrderedDict()
    videos_list = sorted(glob.glob(os.path.join(data_folder, '*')))
    for video in videos_list:
        video_name = video.split('/')[-1]
        videos[video_name] = {}
        videos[video_name]['path'] = video
        videos[video_name]['frame'] = glob.glob(os.path.join(video, '*.jpg'))
        videos[video_name]['frame'].sort()
        videos[video_name]['length'] = len(videos[video_name]['frame'])

    k = 0
    for i,video in enumerate(videos):
        directory = os.getcwd() + ("/output/"+dataset+"/"+"{:03d}").format(i+1)
        if not os.path.exists(directory):
            os.makedirs(directory)
        video_name = video.split('/')[-1]
        for j,frame in enumerate(videos[video_name]['frame']):
            if(labels[0][k] == 1):
                img = cv2.imread(frame)
                cv2.imwrite("./output/"+dataset+"/"+("{:03d}/{:03d}").format(i+1,j+1) + '.jpg',img)
            k += 1

# %%
get_augly_data("ped2")

# %%
get_augly_data("avenue")

# %%
get_augly_data("shanghai")
